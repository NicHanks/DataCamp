# %% [markdown]
# ### The following files are course notes
#
# Intro to python
#
# Intro to ds in Python
#
# Intermediate python
#
# Data Manipulation with pandas
#
# Intro to Functions in Python
#
# Intro to finance in python
#
# Intro to importing data in python
#
# Intro matplotlib
#
# intro seaborn
#
#
#
# Introduction to Shell
#
# Introduction to Data Visualization with Matplotlib
#
# Introduction to Data Visualization with Seaborn
#
# Data Manipulation with pandas
#
# AWS Cloud Technology and Services
#
# AWS Security and Cost Management
#
#
#
#
#
#
#
# Intermediate:
#
# Statistical Thinking in Python (Part 2)
#
# Introduction to Deep Learning in Python
#
# Unsupervised Learning in Python
#
# Introduction to PySpark
#
# Linear Algebra for Data Science in R
#
# Cleaning Data in Python
#
# Supervised Learning with scikit-learn
#
#
#
#
#
# Advanced:
#
# Ensemble Methods in Python
